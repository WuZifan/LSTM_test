# %% [markdown]
# ## RNN时间序列预测
#
#     1、基本方法：
#         1.1 加载时间序列数据。
#         1.2 生成训练数据，x的维度为【batch_size,seq_len,word_vector】，y的维度为【batch_size,1】
#         1.3 比如在我们的例子中，通过sin函数或者股票的收盘价去预测下一时刻的值，假设batch_size为10，
#            那么，我们通过看5天预测一天，x维度就是【10,5,1】。一个seq就是5天的收盘件，最后是1因为
#            每天的收盘价都只用1个维度的数据表示。
#         1.4 预测，预测有两套方案，假设有100天数据，seq长度为5，往后预测一天：
#            1.4.1 方案一：我们利用真实的5天数据，去预测后一天的数据。
#            1.4.2 方案二：除了第一次利用5天真实的数据，之后我们都把预测数据放在seq末尾，并剔除第一天，
#                     以此预测。

# %% [markdown]
# ## 加载数据
#
#     1、加载股票数据和sin数据
#     2、定义获取训练数据和数据归一化的方法

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
'''
股票数据
'''
raw_data=pd.read_csv('data/all_stock_data.csv')

# %%
plt.plot(raw_data.loc[10000:,'Close'])

# %%
'''
sin数据
'''
x=np.asarray(range(0,5001))/100
y=np.asarray([math.sin(aa) for aa in x])
plt.plot(y)

# %%
'''
获取训练数据
'''
def get_train_test(y,seq_len=10,split_per=0.8):
    x_final=[]
    y_final=[]
    window_cnt=int(len(y)/seq_len)
    for i in range(window_cnt):
        x_final.append(y[i*seq_len:(i+1)*seq_len])
        y_final.append(y[(i+1)*seq_len])
    x_final=np.asarray(x_final)
    y_final=np.asarray(y_final)
    
    
    train_len=int(0.8*len(x_final))
    
    x_final_train=np.asarray(x_final[:train_len])
    x_final_train=np.reshape(x_final_train,(x_final_train.shape[0],x_final_train.shape[1],1))
    y_final_train=np.asarray(y_final[:train_len])
    y_final_train=np.reshape(y_final_train,(y_final_train.shape[0],1))
    
    x_final_test=np.asarray(x_final[train_len:])
    x_final_test=np.reshape(x_final_test,(x_final_test.shape[0],x_final_test.shape[1],1))
    y_final_test=np.asarray(y_final[train_len:])
    y_final_test=np.reshape(y_final_test,(y_final_test.shape[0],1))
    
    print(x_final_train.shape,y_final_train.shape)
    print(x_final_test.shape,y_final_test.shape)
    
    return [x_final_train,y_final_train,x_final_test,y_final_test]

'''
数据归一化：min-max归一
'''
def nor_data(y,way='min_max'):
    y_min=min(y)
    y_max=max(y)
    y=(np.asarray(y)-y_min)/(y_max-y_min)
    return y

# %%
data_2017=raw_data.loc[10000:16000,:]
y_close=data_2017['Close'].tolist()
y_close=nor_data(y_close)
result=get_train_test(y_close)
# Out:
# (480, 10, 1) (480, 1)
# (120, 10, 1) (120, 1)

# %%
train=result[0]
label=result[1]
train[1],label[0]
# Out:
# (array([[0.0280015 ],
#         [0.02800858],
#         [0.03174917],
#         [0.03234316],
#         [0.03041982],
#         [0.0298117 ],
#         [0.02626908],
#         [0.02782473],
#         [0.03018647],
#         [0.02906924]]), array([0.0280015]))

# %%
aa=[0,1,2,3,4]
aa[2:4]
aa[4]
# Out:
# 4

# %% [markdown]
# ## 构建模型
#
#     1、加载model模型，训练
#     2、预测

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense
# Out:
# E:\Python\PY3.6\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
'''
构建简单的lstm模型
'''
seq_len=10

def build_model():
    model=Sequential()
    model.add(LSTM(units=100,input_shape=(seq_len,1),return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=100,return_sequences=True))
    model.add(LSTM(units=100,return_sequences=False))
    model.add(Dense(1,activation='linear'))
    model.compile(loss='mse',optimizer='adam',metrics=['mae'])
    return model

# %%
'''
训练
'''
def train_model(model,y_org):
    result=get_train_test(y_org,seq_len=seq_len)
    x_train=result[0]
    y_train=result[1]
    model.fit(x_train,y_train,validation_data=(result[2],result[3]),epochs=20,batch_size=10,shuffle=False)
    return model

# %%
'''
预测:每次用真实的数据预测后面的数据
'''
def my_predict(y_pred,model):
    predict_input=[]
    for i in range(len(y_pred)-seq_len):
        temp=y_pred[i:i+seq_len]
        predict_input.append(temp)
    predict_input=np.asarray(predict_input)
    # 预测时候所用的格式也必须和训练时候一样（batch_size,seq_len,.word_vector）
    # 只不过单个预测的时候，batch_size设置为1
    predict_input=np.reshape(predict_input,(predict_input.shape[0],predict_input.shape[1],1))
    final_pred_result=model.predict_on_batch(predict_input)
    return final_pred_result

'''
预测：除了第一次用真实数据外，后面都用预测出来的值作为输入
'''
def my_predict_2(y_pred,model):
    predict_input=[]
    final_result=[]
    y_pred=list(y_pred)
    for i in range(len(y_pred)-seq_len):
        if i==0:
            temp=y_pred[i:i+seq_len]
            final_result=y_pred[i:i+seq_len]
        else:
            temp.append(temp_pred)
            temp.pop(0)
#             print(temp)
            
        temp_in=np.asarray(temp)
        temp_in=np.reshape(temp_in,(1,temp_in.shape[0],1))
        temp_pred=model.predict(temp_in)
        temp_pred=temp_pred[0][0]
        final_result.append(temp_pred)
    return final_result

# %%
'''
流水线
'''
def pipline(y_org):
    # 建立模型
    model=build_model()
    # 获得原始数据
    y_org=y_org
    # 训练模型
    model=train_model(model,y_org)
    # 预测
    pre_result=my_predict(y_org,model)
    # 绘图
    plt.figure(figsize=(5,5))
    plt.plot(y_org)
    plt.plot(pre_result)
    
#     return pre_result

# %%
result=pipline(y_close)
# Out:
# (480, 10, 1) (480, 1)
# (120, 10, 1) (120, 1)
# Train on 480 samples, validate on 120 samples
# Epoch 1/20
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0025 - mean_absolute_error: 0.0370 - val_loss: 0.0061 - val_mean_absolute_error: 0.0628
# Epoch 2/20
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0267 - mean_absolute_error: 0.1371 - val_loss: 0.0330 - val_mean_absolute_error: 0.1590
# Epoch 3/20
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0770 - mean_absolute_error: 0.2260 - val_loss: 0.0129 - val_mean_absolute_error: 0.0994
# Epoch 4/20
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0124 - mean_absolute_error: 0.0917 - val_loss: 0.0017 - val_mean_absolute_error: 0.0351
# Epoch 5/20
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0044 - mean_absolute_error: 0.0531 - val_loss: 0.0031 - val_mean_absolute_error: 0.0520
# Epoch 6/20
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0331 - val_loss: 0.0012 - val_mean_absolute_error: 0.0304
# Epoch 7/20
# 480/480 [==============================] - 1s 1ms/step - loss: 6.5820e-04 - mean_absolute_error: 0.0192 - val_loss: 3.5997e-04 - val_mean_absolute_error: 0.0155
# Epoch 8/20
# 480/480 [==============================] - 1s 1ms/step - loss: 7.0897e-04 - mean_absolute_error: 0.0215 - val_loss: 3.5502e-04 - val_mean_absolute_error: 0.0145
# Epoch 9/20
# 480/480 [==============================] - 1s 1ms/step - loss: 4.3619e-04 - mean_absolute_error: 0.0159 - val_loss: 3.6600e-04 - val_mean_absolute_error: 0.0150
# Epoch 10/20
# 480/480 [==============================] - 1s 1ms/step - loss: 3.0396e-04 - mean_absolute_error: 0.0125 - val_loss: 4.2764e-04 - val_mean_absolute_error: 0.0170
# Epoch 11/20
# 480/480 [==============================] - 1s 1ms/step - loss: 5.9709e-04 - mean_absolute_error: 0.0196 - val_loss: 6.7629e-04 - val_mean_absolute_error: 0.0194
# Epoch 12/20
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0013 - mean_absolute_error: 0.0296 - val_loss: 0.0018 - val_mean_absolute_error: 0.0355
# Epoch 13/20
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0028 - mean_absolute_error: 0.0432 - val_loss: 0.0075 - val_mean_absolute_error: 0.0796
# Epoch 14/20
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0041 - mean_absolute_error: 0.0500 - val_loss: 0.0170 - val_mean_absolute_error: 0.1245
# Epoch 15/20
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0014 - mean_absolute_error: 0.0312 - val_loss: 0.0018 - val_mean_absolute_error: 0.0371
# Epoch 16/20
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0233 - mean_absolute_error: 0.1314 - val_loss: 0.0363 - val_mean_absolute_error: 0.1853
# Epoch 17/20
# 480/480 [==============================] - 1s 1ms/step - loss: 0.0094 - mean_absolute_error: 0.0623 - val_loss: 5.3618e-04 - val_mean_absolute_error: 0.0177
# Epoch 18/20
# 480/480 [==============================] - 1s 1ms/step - loss: 4.2090e-04 - mean_absolute_error: 0.0141 - val_loss: 6.2120e-04 - val_mean_absolute_error: 0.0197
# Epoch 19/20
# 480/480 [==============================] - 1s 1ms/step - loss: 6.7597e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0017 - val_mean_absolute_error: 0.0365
# Epoch 20/20
# 480/480 [==============================] - 1s 1ms/step - loss: 5.6294e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0012 - val_mean_absolute_error: 0.0302

# %% [markdown]
# ## 问题：
#
#     1、突然想起来这个是和我之前做件量预测遇到的问题一样：
#         1.1 即，利用预测出来的值再去做预测时，往往会得到特别糟糕的答案。
#
#     2、尝试使用另一种模型构建的方式
